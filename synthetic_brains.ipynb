# %% [markdown]
# **The goal of this GenAI project is to create a Machine Learning Model capable of generating different types of 3D ```.nii``` Brain scans which contain malignant tumor.**
#
# This notebook contains the ```python``` code as well as the related documentation.
#
# There are two approaches being experimented with:
# 1. Turning 3D ```.nii``` scans into 155 individual 2D ```.png``` slices and using those to train the GAN, and in turn, the GAN will generate 2D slices.
# 2. Training the GAN on vectorized 3D ```.nii``` files, and in turn, the GAN will also generate a 3D model which can later be converted to a ```.nii``` file.

# %% [markdown]
# Installing the required Libraries:

# %%
# %pip install boto3 nibabel numpy matplotlib scikit-image opencv-python
# Out:
# Requirement already satisfied: boto3 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (1.35.44)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: nibabel in c:\users\user\anaconda3\envs\myenv\lib\site-packages (5.3.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\myenv\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\myenv\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-image in c:\users\user\anaconda3\envs\myenv\lib\site-packages (0.24.0)
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\envs\myenv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: botocore<1.36.0,>=1.35.44 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from boto3) (1.35.44)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from boto3) (0.10.3)
# Requirement already satisfied: packaging>=20 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from nibabel) (24.1)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from nibabel) (4.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.9 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from scikit-image) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from scikit-image) (2024.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from scikit-image) (0.4)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from botocore<1.36.0,>=1.35.44->boto3) (2.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# Importing those Libraries:

# %%
import boto3
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import io
import tempfile
import os

# %% [markdown]
# **In this Cell, we will be rendering the ```.nii``` files  from the S3 Bucket, and then saving each one as a collection of 2D ```.png``` slices in the S3 Bucket.**
# 1. First, we will connect to our bucket using the ```boto3``` library.
# 2. Next, we define our  ```crop``` values, which will be used to crop out the useless data.
# 3. Then, we define our two important functions for rendering data for the user to see and for saving the data as slices.
#
# **For the Rendering Function:**
#
# We define our function  ```render_nii_from_s3()``` which uses a ```.nii``` file to show the middle 2D Brain Slice.
# 1. The function takes in a ```.nii``` ```filename```, and finds it in the S3 Bucket.
# 2. Using a ```tempfile```, the ```.nii``` file is stored.
# 3. The ```data``` is then read from the ```tempfile```. (It is a vector now.)
# 3. The middle index is then found from the ```data``` vector, and then ```matplotlib```'s ```pyplot``` finally displays it in ```grayscale``` using the appropriate title.
# 4. The function also handles any errors that could arise in the entire process, such as the the ```.nii``` file being empty or corrupted, or errors which could arise when loading the ```.nii``` file or displaying the ```slice```.
#
# **For the Saving Function:**
#
# We define our function ```save_png_from_nii()``` which uses a ```.nii``` file and stores it as a collection of ```.png``` images in the S3 Bucket.
# 1. The function takes in a ```.nii``` ```filename```, and finds it in the S3 Bucket.
# 2. Using a ```tempfile```, the ```.nii``` file is stored.
# 3. The ```data``` is then read from the ```tempfile```. (It is a vector now.)
# 4. The ```crop``` is then applied to the ```data``` using the ```crop``` values defined at the start.
# 5.

# %%
# Setting up the data pipeline to access the 5 brains in the AWS S3 Bucket folder path:

s3 = boto3.resource('s3')
bucket_name = 'chemocraft-data'
folder_path = 'MICCAI_BraTS2020_TrainingData/'
bucket = s3.Bucket(bucket_name)

# Setting Crop values for Data Preprocessing:

crop_left, crop_right = 20, 10
crop_top, crop_bottom = 30, 30

def render_nii_from_s3(filename): # Function to display the middle slice of each brain scan type
    print(f"Fetching file: {filename}")

    obj = bucket.Object(folder_path + filename)
    file_stream = io.BytesIO(obj.get()['Body'].read())

    # Using temp files for efficent computing:

    with tempfile.NamedTemporaryFile(suffix='.nii', delete=False) as temp_file:  # Disable auto-delete
        temp_file.write(file_stream.getvalue())
        temp_file.flush()

        temp_file_path = temp_file.name
        print(f"Temporary file created: {temp_file_path}")

    try:
        img = nib.load(temp_file_path)
        data = img.get_fdata() # Storing brain into data variable

        print(f"Data shape for {filename}: {data.shape}") # Displaying shape of each brain

        if data.size == 0: # if data is nonexistent
            print(f"No data found in {filename}")
            return

        slice_idx = data.shape[2] // 2 # Getting index of middle slice to display it

        plt.figure(figsize=(3, 3)) # Displaying in 3x3 square
        plt.imshow(data[:, :, slice_idx], cmap='gray') # Color is set to grayscale
        plt.title(f'{filename} - Slice {slice_idx}') # Creating a title for the image
        plt.axis('off')  # Hide axes for cleaner display
        plt.show() # Finally showing the image

    except Exception as e:
        print(f"Error loading file {filename}: {e}") # Reports problems with getting the file
    finally:
        try:
            os.remove(temp_file_path)  # We do not want to save files locally, so we now delete the temp files
            print(f"Deleted temporary file: {temp_file_path}")
        except OSError as cleanup_error:
            print(f"Error deleting temp file: {cleanup_error}")

def save_png_from_nii(filename): # Function which will save .png grayscale brain slices to AWS S3 Buckets
    print(f"Fetching file: {filename}")
    obj = bucket.Object(folder_path + filename)
    file_stream = io.BytesIO(obj.get()['Body'].read())

    with tempfile.NamedTemporaryFile(suffix='.nii', delete=False) as temp_file:  # Disable auto-delete
        temp_file.write(file_stream.getvalue())
        temp_file.flush()

        temp_file_path = temp_file.name
        print(f"Temporary file created: {temp_file_path}")
    
        try:
            img = nib.load(temp_file_path)
            data = img.get_fdata()
            
            start_y = crop_top
            end_y = data.shape[0] - crop_bottom
            start_x = crop_left
            end_x = data.shape[1] - crop_right

            if data.size == 0:
                print(f"No data found in {filename}")
                return
            
            for slice_idx in range(data.shape[2]): # For each slice of each brain
                slice_2d = data[:, :, slice_idx]
                cropped_slice = slice_2d[start_y:end_y, start_x:end_x]

                filename = filename.removesuffix(".nii") # Removes the .nii part

                # Folder for each brain inside the Brain_Slices:

                brain_number = filename.split('_')[-2]
                scan_type = filename.split('_')[-1]

                slice_path = f"brain_slices/{brain_number}/{scan_type}"
                print(f"Saving file in directory: {slice_path}") 

                png_filename = f"{slice_path}/{slice_idx}.png" 
                
                with tempfile.NamedTemporaryFile(suffix= '.png', delete=False) as temp_png: # This part creates a temp png .file used to save the grayscale brain slice
                    mpimg.imsave(temp_png.name, cropped_slice, cmap='gray')
                    temp_png.flush()
                    temp_png.seek(0)
                    temp_png_name = temp_png.name
                try: 
                    s3.Bucket(bucket_name).upload_file(temp_png_name, f"tanmay/{png_filename}")
                    os.remove(temp_png_name)
                except Exception as e:
                    print(f"Error saving file: {png_filename}, {e}")
                    
        except Exception as e:
            print(f"Error saving file {filename}: {e}")

found_files = False

i=0 # Counter for the number of brains

for obj in bucket.objects.filter(Prefix=folder_path):
    if obj.key.endswith('.nii'):
        found_files = True
        # print(obj.key)
        filename = obj.key.split('/')[-2] + '/' + obj.key.split('/')[-1]  # Get the filename 
        # render_nii_from_s3(filename)
        # save_png_from_nii(filename)
        i+=1

print(f"There are {i} brains. ('.nii' files)")
if not found_files:
    print(f"No .nii files found in the folder {folder_path}")
# Out:
# There are 495 brains. ('.nii' files)

# %% [markdown]
# Defining the GAN Architecture
# 1. The Generator
# 2. The Discriminator
# 3. Connecting the Generator & Discriminator
# 4. Compiling the Model

# %% [markdown]
# The Generator:

# %%
# Generator's output shape must be the same shape as the cropped real image: (210, 180, 1)

from tensorflow.keras import layers, models

dim = 100

def build_generator(latent_dim, output_shape=(210, 180, 1)):
    model = models.Sequential(name="ChemoCraft_Generator")
    print("Building Generator")

    model.add(layers.Input(shape=(latent_dim,)))
    model.add(layers.Dense(128, activation="relu"))
    model.add(layers.Dense(256 * 32, activation="relu"))
    model.add(layers.Reshape(target_shape=(16, 16, 32)))
    model.add(layers.Conv2DTranspose(filters=32, kernel_size=5, strides=6, padding="same", activation="relu"))
    model.add(layers.Conv2DTranspose(filters=8, kernel_size=3, strides=5, padding="same", activation="relu"))
    
    prev_out = model.layers[-1].output.shape

    model.add(layers.Conv2D(1, kernel_size=(prev_out[1]-output_shape[0]+1, prev_out[2]-output_shape[1]+1), strides=1, padding="valid", activation="tanh"))

    return model

chemocraft_generator = build_generator(latent_dim=dim)
chemocraft_generator.summary()
# Out:
# Building Generator
# Model: "ChemoCraft_Generator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        12,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8192)           │     1,056,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose                │ (None, 96, 96, 32)     │        25,632 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_1              │ (None, 480, 480, 8)    │         2,312 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 210, 180, 1)    │       652,569 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,750,209 (6.68 MB)
#  Trainable params: 1,750,209 (6.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The Discriminator:

# %%
# Discriminator's input shape should be the same shape as the generator's output: (210, 180, 1)

shape = (210, 180, 1)

def build_discriminator(input_shape=(210, 180, 1)):

    model = models.Sequential(name="ChemoCraft_Discriminator")
    print("Building Discriminator Model")

    model.add(layers.Input(shape=input_shape))
    model.add(layers.Conv2D(filters=16, kernel_size=9, strides=5, padding="same", activation="relu")) 
    model.add(layers.Conv2D(filters=32, kernel_size=5, strides=4, padding="same", activation="relu"))
    model.add(layers.Conv2D(filters=128, kernel_size=3, strides=3, padding="same", activation="relu"))
    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation="sigmoid", name="output"))

    return model
   
chemocraft_discriminator = build_discriminator(shape)
chemocraft_discriminator.summary()
# Out:
# Building Discriminator Model
# Model: "ChemoCraft_Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 42, 36, 16)     │         1,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 11, 9, 32)      │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 3, 128)      │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1536)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │         1,537 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,673 (205.75 KB)
#  Trainable params: 52,673 (205.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Connecting Generator & Discriminator through the GAN:

# %%
def compile_gan(generator, discriminator, latent_dim):
    discriminator.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    z = layers.Input(shape=(latent_dim,))
    img = generator(z)
    discriminator.trainable = False
    validity = discriminator(img)
    gan = models.Model(z, validity)
    gan.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
    return gan

chemocraft_gan = compile_gan(chemocraft_generator, chemocraft_discriminator,latent_dim=dim)
chemocraft_gan.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ChemoCraft_Generator            │ (None, 210, 180, 1)    │     1,750,209 │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ChemoCraft_Discriminator        │ (None, 1)              │        52,673 │
# │ (Sequential)                    │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,802,882 (6.88 MB)
#  Trainable params: 1,750,209 (6.68 MB)
#  Non-trainable params: 52,673 (205.75 KB)

# %% [markdown]
# Setting up Data Pipeline for Training:

# %%
s3 = boto3.resource('s3')
bucket_name = 'chemocraft-data'
folder_path = 'MICCAI_BraTS2020_TrainingData/'
bucket = s3.Bucket(bucket_name)

folder_path = 'tanmay/brain_slices/'

keys = []

for obj in bucket.objects.filter(Prefix=folder_path):
    if obj.key.endswith('.png'):
        sample_key = obj.key.split('/')[-3] # Getting the Brain numbers.
        if sample_key not in keys:
            keys.append(sample_key)

print(len(keys))
# Out:
# 99

# %%
from keras.preprocessing.image import load_img

folder_path = 'tanmay/brain_slices/'

def load_images(bucket_name, folder_path, folder_suffix):
    directory = f"{folder_path}{folder_suffix}/"
    print(f"Loading images from S3 Bucket: {bucket_name}{directory}")
    images = []

    for obj in bucket_name.objects.filter(Prefix=directory):
        if obj.key.endswith('.png'):
            try:
                file_stream = io.BytesIO(obj.get()['Body'].read())
                image = load_img(file_stream, target_size=(210, 180), color_mode='grayscale')
                print(f"Adding {obj.key.removeprefix("tanmay/brain_slices/")} into an array.")
                image = np.array(image) / 255.0  # Normalize to [0, 1]
                images.append(image)
            
            except Exception as e:
                print(f"Error loading image {obj.key}: {e}")

    return np.array(images)

my_arr = load_images(bucket_name=bucket, folder_path=folder_path, folder_suffix="320/flair") # Testing functionality on a small folder
print(my_arr.shape)
# Out:
# Loading images from S3 Bucket: s3.Bucket(name='chemocraft-data')tanmay/brain_slices/320/flair/
# Adding 320/flair/0.png into an array.
# Adding 320/flair/1.png into an array.
# Adding 320/flair/10.png into an array.
# Adding 320/flair/100.png into an array.
# Adding 320/flair/101.png into an array.
# Adding 320/flair/102.png into an array.
# Adding 320/flair/103.png into an array.
# Adding 320/flair/104.png into an array.
# Adding 320/flair/105.png into an array.
# Adding 320/flair/106.png into an array.
# Adding 320/flair/107.png into an array.
# Adding 320/flair/108.png into an array.
# Adding 320/flair/109.png into an array.
# Adding 320/flair/11.png into an array.
# Adding 320/flair/110.png into an array.
# Adding 320/flair/111.png into an array.
# Adding 320/flair/112.png into an array.
# Adding 320/flair/113.png into an array.
# Adding 320/flair/114.png into an array.
# Adding 320/flair/115.png into an array.
# Adding 320/flair/116.png into an array.
# Adding 320/flair/117.png into an array.
# Adding 320/flair/118.png into an array.
# Adding 320/flair/119.png into an array.
# Adding 320/flair/12.png into an array.
# Adding 320/flair/120.png into an array.
# Adding 320/flair/121.png into an array.
# Adding 320/flair/122.png into an array.
# Adding 320/flair/123.png into an array.
# Adding 320/flair/124.png into an array.
# Adding 320/flair/125.png into an array.
# Adding 320/flair/126.png into an array.
# Adding 320/flair/127.png into an array.
# Adding 320/flair/128.png into an array.
# Adding 320/flair/129.png into an array.
# Adding 320/flair/13.png into an array.
# Adding 320/flair/130.png into an array.
# Adding 320/flair/131.png into an array.
# Adding 320/flair/132.png into an array.
# Adding 320/flair/133.png into an array.
# Adding 320/flair/134.png into an array.
# Adding 320/flair/135.png into an array.
# Adding 320/flair/136.png into an array.
# Adding 320/flair/137.png into an array.
# Adding 320/flair/138.png into an array.
# Adding 320/flair/139.png into an array.
# Adding 320/flair/14.png into an array.
# Adding 320/flair/140.png into an array.
# Adding 320/flair/141.png into an array.
# Adding 320/flair/142.png into an array.
# Adding 320/flair/143.png into an array.
# Adding 320/flair/144.png into an array.
# Adding 320/flair/145.png into an array.
# Adding 320/flair/146.png into an array.
# Adding 320/flair/147.png into an array.
# Adding 320/flair/148.png into an array.
# Adding 320/flair/149.png into an array.
# Adding 320/flair/15.png into an array.
# Adding 320/flair/150.png into an array.
# Adding 320/flair/151.png into an array.
# Adding 320/flair/152.png into an array.
# Adding 320/flair/153.png into an array.
# Adding 320/flair/154.png into an array.
# Adding 320/flair/16.png into an array.
# Adding 320/flair/17.png into an array.
# Adding 320/flair/18.png into an array.
# Adding 320/flair/19.png into an array.
# Adding 320/flair/2.png into an array.
# Adding 320/flair/20.png into an array.
# Adding 320/flair/21.png into an array.
# Adding 320/flair/22.png into an array.
# Adding 320/flair/23.png into an array.
# Adding 320/flair/24.png into an array.
# Adding 320/flair/25.png into an array.
# Adding 320/flair/26.png into an array.
# Adding 320/flair/27.png into an array.
# Adding 320/flair/28.png into an array.
# Adding 320/flair/29.png into an array.
# Adding 320/flair/3.png into an array.
# Adding 320/flair/30.png into an array.
# Adding 320/flair/31.png into an array.
# Adding 320/flair/32.png into an array.
# Adding 320/flair/33.png into an array.
# Adding 320/flair/34.png into an array.
# Adding 320/flair/35.png into an array.
# Adding 320/flair/36.png into an array.
# Adding 320/flair/37.png into an array.
# Adding 320/flair/38.png into an array.
# Adding 320/flair/39.png into an array.
# Adding 320/flair/4.png into an array.
# Adding 320/flair/40.png into an array.
# Adding 320/flair/41.png into an array.
# Adding 320/flair/42.png into an array.
# Adding 320/flair/43.png into an array.
# Adding 320/flair/44.png into an array.
# Adding 320/flair/45.png into an array.
# Adding 320/flair/46.png into an array.
# Adding 320/flair/47.png into an array.
# Adding 320/flair/48.png into an array.
# Adding 320/flair/49.png into an array.
# Adding 320/flair/5.png into an array.
# Adding 320/flair/50.png into an array.
# Adding 320/flair/51.png into an array.
# Adding 320/flair/52.png into an array.
# Adding 320/flair/53.png into an array.
# Adding 320/flair/54.png into an array.
# Adding 320/flair/55.png into an array.
# Adding 320/flair/56.png into an array.
# Adding 320/flair/57.png into an array.
# Adding 320/flair/58.png into an array.
# Adding 320/flair/59.png into an array.
# Adding 320/flair/6.png into an array.
# Adding 320/flair/60.png into an array.
# Adding 320/flair/61.png into an array.
# Adding 320/flair/62.png into an array.
# Adding 320/flair/63.png into an array.
# Adding 320/flair/64.png into an array.
# Adding 320/flair/65.png into an array.
# Adding 320/flair/66.png into an array.
# Adding 320/flair/67.png into an array.
# Adding 320/flair/68.png into an array.
# Adding 320/flair/69.png into an array.
# Adding 320/flair/7.png into an array.
# Adding 320/flair/70.png into an array.
# Adding 320/flair/71.png into an array.
# Adding 320/flair/72.png into an array.
# Adding 320/flair/73.png into an array.
# Adding 320/flair/74.png into an array.
# Adding 320/flair/75.png into an array.
# Adding 320/flair/76.png into an array.
# Adding 320/flair/77.png into an array.
# Adding 320/flair/78.png into an array.
# Adding 320/flair/79.png into an array.
# Adding 320/flair/8.png into an array.
# Adding 320/flair/80.png into an array.
# Adding 320/flair/81.png into an array.
# Adding 320/flair/82.png into an array.
# Adding 320/flair/83.png into an array.
# Adding 320/flair/84.png into an array.
# Adding 320/flair/85.png into an array.
# Adding 320/flair/86.png into an array.
# Adding 320/flair/87.png into an array.
# Adding 320/flair/88.png into an array.
# Adding 320/flair/89.png into an array.
# Adding 320/flair/9.png into an array.
# Adding 320/flair/90.png into an array.
# Adding 320/flair/91.png into an array.
# Adding 320/flair/92.png into an array.
# Adding 320/flair/93.png into an array.
# Adding 320/flair/94.png into an array.
# Adding 320/flair/95.png into an array.
# Adding 320/flair/96.png into an array.
# Adding 320/flair/97.png into an array.
# Adding 320/flair/98.png into an array.
# Adding 320/flair/99.png into an array.
# (155, 210, 180)

# %% [markdown]
# Batch Training:

# %%
import tensorflow as tf

def train_gan(generator, latent_dim, discriminator, gan, training_array, batch_size):
    for _ in range(len(training_array) // batch_size):
        # Select random batch of real images
        idx = np.random.randint(0, len(training_array), batch_size)
        real_slices = np.array([training_array[i] for i in idx])

        # Generate fake images
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        fake_slices = generator.predict(noise)

        # Train the discriminator
        d_loss_real = discriminator.train_on_batch(real_slices, np.ones((batch_size, 1)))
        d_loss_fake = discriminator.train_on_batch(fake_slices, np.zeros((batch_size, 1)))
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Train the generator
        noise = np.random.normal(0, 1, (batch_size, latent_dim))
        g_loss = gan.train_on_batch(noise, np.ones((batch_size, 1)))

        print(f"D Loss: {d_loss[0]}, G Loss: {g_loss[0]}")

# %%
folder_path = 'tanmay/brain_slices/'

epochs = 150

for epoch in range(epochs):
    for key in keys:
        brain_array = load_images(bucket_name=bucket, folder_path=folder_path, folder_suffix=key)
        print("Training Gan now:")
        train_gan(generator=chemocraft_generator, latent_dim=dim, discriminator=chemocraft_discriminator, gan=chemocraft_gan, training_array=brain_array, batch_size=5)
        print(f"Epoch {epoch + 1}/{epochs}")
# Out:
# Loading images from S3 Bucket: s3.Bucket(name='chemocraft-data')tanmay/brain_slices/002/
# Adding 002/flair/0.png into an array.
# Adding 002/flair/1.png into an array.
# Adding 002/flair/10.png into an array.
# Adding 002/flair/100.png into an array.
# Adding 002/flair/101.png into an array.
# Adding 002/flair/102.png into an array.
# Adding 002/flair/103.png into an array.
# Adding 002/flair/104.png into an array.
# Adding 002/flair/105.png into an array.
# Adding 002/flair/106.png into an array.
# Adding 002/flair/107.png into an array.
# Adding 002/flair/108.png into an array.
# Adding 002/flair/109.png into an array.
# Adding 002/flair/11.png into an array.
# Adding 002/flair/110.png into an array.
# Adding 002/flair/111.png into an array.
# Adding 002/flair/112.png into an array.
# Adding 002/flair/113.png into an array.
# Adding 002/flair/114.png into an array.
# Adding 002/flair/115.png into an array.
# Adding 002/flair/116.png into an array.
# Adding 002/flair/117.png into an array.
# Adding 002/flair/118.png into an array.
# Adding 002/flair/119.png into an array.
# Adding 002/flair/12.png into an array.
# Adding 002/flair/120.png into an array.
# Adding 002/flair/121.png into an array.
# Adding 002/flair/122.png into an array.
# Adding 002/flair/123.png into an array.
# Adding 002/flair/124.png into an array.
# Adding 002/flair/125.png into an array.
# Adding 002/flair/126.png into an array.
# Adding 002/flair/127.png into an array.
# Adding 002/flair/128.png into an array.
# Adding 002/flair/129.png into an array.
# Adding 002/flair/13.png into an array.
# Adding 002/flair/130.png into an array.
# Adding 002/flair/131.png into an array.
# Adding 002/flair/132.png into an array.
# Adding 002/flair/133.png into an array.
# Adding 002/flair/134.png into an array.
# Adding 002/flair/135.png into an array.
# Adding 002/flair/136.png into an array.
# Adding 002/flair/137.png into an array.
# Adding 002/flair/138.png into an array.
# Adding 002/flair/139.png into an array.
# Adding 002/flair/14.png into an array.
# Adding 002/flair/140.png into an array.
# Adding 002/flair/141.png into an array.
# Adding 002/flair/142.png into an array.
# Adding 002/flair/143.png into an array.
# Adding 002/flair/144.png into an array.
# Adding 002/flair/145.png into an array.
# Adding 002/flair/146.png into an array.
# Adding 002/flair/147.png into an array.
# Adding 002/flair/148.png into an array.
# Adding 002/flair/149.png into an array.
# Adding 002/flair/15.png into an array.
# Adding 002/flair/150.png into an array.
# Adding 002/flair/151.png into an array.
# Adding 002/flair/152.png into an array.
# Adding 002/flair/153.png into an array.
# Adding 002/flair/154.png into an array.
# Adding 002/flair/16.png into an array.
# Adding 002/flair/17.png into an array.
# Adding 002/flair/18.png into an array.
# Adding 002/flair/19.png into an array.
# Adding 002/flair/2.png into an array.
# Adding 002/flair/20.png into an array.
# Adding 002/flair/21.png into an array.
# Adding 002/flair/22.png into an array.
# Adding 002/flair/23.png into an array.
# Adding 002/flair/24.png into an array.
# Adding 002/flair/25.png into an array.
# Adding 002/flair/26.png into an array.
# Adding 002/flair/27.png into an array.
# Adding 002/flair/28.png into an array.
# Adding 002/flair/29.png into an array.
# Adding 002/flair/3.png into an array.
# Adding 002/flair/30.png into an array.
# Adding 002/flair/31.png into an array.
# Adding 002/flair/32.png into an array.
# Adding 002/flair/33.png into an array.
# Adding 002/flair/34.png into an array.
# Adding 002/flair/35.png into an array.
# Adding 002/flair/36.png into an array.
# Adding 002/flair/37.png into an array.
# Adding 002/flair/38.png into an array.
# Adding 002/flair/39.png into an array.
# Adding 002/flair/4.png into an array.
# Adding 002/flair/40.png into an array.
# Adding 002/flair/41.png into an array.
# Adding 002/flair/42.png into an array.
# Adding 002/flair/43.png into an array.
# Adding 002/flair/44.png into an array.
# Adding 002/flair/45.png into an array.
# Adding 002/flair/46.png into an array.
# Adding 002/flair/47.png into an array.
# Adding 002/flair/48.png into an array.
# Adding 002/flair/49.png into an array.
# Adding 002/flair/5.png into an array.
# Adding 002/flair/50.png into an array.
# Adding 002/flair/51.png into an array.
# Adding 002/flair/52.png into an array.
# Adding 002/flair/53.png into an array.
# Adding 002/flair/54.png into an array.
# Adding 002/flair/55.png into an array.
# Adding 002/flair/56.png into an array.
# Adding 002/flair/57.png into an array.
# Adding 002/flair/58.png into an array.
# Adding 002/flair/59.png into an array.
# Adding 002/flair/6.png into an array.
# Adding 002/flair/60.png into an array.
# Adding 002/flair/61.png into an array.
# Adding 002/flair/62.png into an array.
# Adding 002/flair/63.png into an array.
# Adding 002/flair/64.png into an array.
# Adding 002/flair/65.png into an array.
# Adding 002/flair/66.png into an array.
# Adding 002/flair/67.png into an array.
# Adding 002/flair/68.png into an array.
# Adding 002/flair/69.png into an array.
# Adding 002/flair/7.png into an array.
# Adding 002/flair/70.png into an array.
# Adding 002/flair/71.png into an array.
# Adding 002/flair/72.png into an array.
# Adding 002/flair/73.png into an array.
# Adding 002/flair/74.png into an array.
# Adding 002/flair/75.png into an array.
# Adding 002/flair/76.png into an array.
# Adding 002/flair/77.png into an array.
# Adding 002/flair/78.png into an array.
# Adding 002/flair/79.png into an array.
# Adding 002/flair/8.png into an array.
# Adding 002/flair/80.png into an array.
# Adding 002/flair/81.png into an array.
# Adding 002/flair/82.png into an array.
# Adding 002/flair/83.png into an array.
# Adding 002/flair/84.png into an array.
# Adding 002/flair/85.png into an array.
# Adding 002/flair/86.png into an array.
# Adding 002/flair/87.png into an array.
# Adding 002/flair/88.png into an array.
# Adding 002/flair/89.png into an array.
# Adding 002/flair/9.png into an array.
# Adding 002/flair/90.png into an array.
# Adding 002/flair/91.png into an array.
# Adding 002/flair/92.png into an array.
# Adding 002/flair/93.png into an array.
# Adding 002/flair/94.png into an array.
# Adding 002/flair/95.png into an array.
# Adding 002/flair/96.png into an array.
# Adding 002/flair/97.png into an array.
# Adding 002/flair/98.png into an array.
# Adding 002/flair/99.png into an array.
# Adding 002/seg/0.png into an array.
# Adding 002/seg/1.png into an array.
# Adding 002/seg/10.png into an array.
# Adding 002/seg/100.png into an array.
# Adding 002/seg/101.png into an array.
# Adding 002/seg/102.png into an array.
# Adding 002/seg/103.png into an array.
# Adding 002/seg/104.png into an array.
# Adding 002/seg/105.png into an array.
# Adding 002/seg/106.png into an array.
# Adding 002/seg/107.png into an array.
# Adding 002/seg/108.png into an array.
# Adding 002/seg/109.png into an array.
# Adding 002/seg/11.png into an array.
# Adding 002/seg/110.png into an array.
# Adding 002/seg/111.png into an array.
# Adding 002/seg/112.png into an array.
# Adding 002/seg/113.png into an array.
# Adding 002/seg/114.png into an array.
# Adding 002/seg/115.png into an array.
# Adding 002/seg/116.png into an array.
# Adding 002/seg/117.png into an array.
# Adding 002/seg/118.png into an array.
# Adding 002/seg/119.png into an array.
# Adding 002/seg/12.png into an array.
# Adding 002/seg/120.png into an array.
# Adding 002/seg/121.png into an array.
# Adding 002/seg/122.png into an array.
# Adding 002/seg/123.png into an array.
# Adding 002/seg/124.png into an array.
# Adding 002/seg/125.png into an array.
# Adding 002/seg/126.png into an array.
# Adding 002/seg/127.png into an array.
# Adding 002/seg/128.png into an array.
# Adding 002/seg/129.png into an array.
# Adding 002/seg/13.png into an array.
# Adding 002/seg/130.png into an array.
# Adding 002/seg/131.png into an array.
# Adding 002/seg/132.png into an array.
# Adding 002/seg/133.png into an array.
# Adding 002/seg/134.png into an array.
# Adding 002/seg/135.png into an array.
# Adding 002/seg/136.png into an array.
# Adding 002/seg/137.png into an array.
# Adding 002/seg/138.png into an array.
# Adding 002/seg/139.png into an array.
# Adding 002/seg/14.png into an array.
# Adding 002/seg/140.png into an array.
# Adding 002/seg/141.png into an array.
# Adding 002/seg/142.png into an array.
# Adding 002/seg/143.png into an array.
# Adding 002/seg/144.png into an array.
# Adding 002/seg/145.png into an array.
# Adding 002/seg/146.png into an array.
# Adding 002/seg/147.png into an array.
# Adding 002/seg/148.png into an array.
# Adding 002/seg/149.png into an array.
# Adding 002/seg/15.png into an array.
# Adding 002/seg/150.png into an array.
# Adding 002/seg/151.png into an array.
# Adding 002/seg/152.png into an array.
# Adding 002/seg/153.png into an array.
# Adding 002/seg/154.png into an array.
# Adding 002/seg/16.png into an array.
# Adding 002/seg/17.png into an array.
# Adding 002/seg/18.png into an array.
# Adding 002/seg/19.png into an array.
# Adding 002/seg/2.png into an array.
# Adding 002/seg/20.png into an array.
# Adding 002/seg/21.png into an array.
# Adding 002/seg/22.png into an array.
# Adding 002/seg/23.png into an array.
# Adding 002/seg/24.png into an array.
# Adding 002/seg/25.png into an array.
# Adding 002/seg/26.png into an array.
# Adding 002/seg/27.png into an array.
# Adding 002/seg/28.png into an array.
# Adding 002/seg/29.png into an array.
# Adding 002/seg/3.png into an array.
# Adding 002/seg/30.png into an array.
# Adding 002/seg/31.png into an array.
# Adding 002/seg/32.png into an array.
# Adding 002/seg/33.png into an array.
# Adding 002/seg/34.png into an array.
# Adding 002/seg/35.png into an array.
# Adding 002/seg/36.png into an array.
# Adding 002/seg/37.png into an array.
# Adding 002/seg/38.png into an array.
# Adding 002/seg/39.png into an array.
# Adding 002/seg/4.png into an array.
# Adding 002/seg/40.png into an array.
# Adding 002/seg/41.png into an array.
# Adding 002/seg/42.png into an array.
# Adding 002/seg/43.png into an array.
# Adding 002/seg/44.png into an array.
# Adding 002/seg/45.png into an array.
# Adding 002/seg/46.png into an array.
# Adding 002/seg/47.png into an array.
# Adding 002/seg/48.png into an array.
# Adding 002/seg/49.png into an array.
# Adding 002/seg/5.png into an array.
# Adding 002/seg/50.png into an array.
# Adding 002/seg/51.png into an array.
# Adding 002/seg/52.png into an array.
# Adding 002/seg/53.png into an array.
# Adding 002/seg/54.png into an array.
# Adding 002/seg/55.png into an array.
# Adding 002/seg/56.png into an array.
# Adding 002/seg/57.png into an array.
# Adding 002/seg/58.png into an array.
# Adding 002/seg/59.png into an array.
# Adding 002/seg/6.png into an array.
# Adding 002/seg/60.png into an array.
# Adding 002/seg/61.png into an array.
# Adding 002/seg/62.png into an array.
# Adding 002/seg/63.png into an array.
# Adding 002/seg/64.png into an array.
# Adding 002/seg/65.png into an array.
# Adding 002/seg/66.png into an array.
# Adding 002/seg/67.png into an array.
# Adding 002/seg/68.png into an array.
# Adding 002/seg/69.png into an array.
# Adding 002/seg/7.png into an array.
# Adding 002/seg/70.png into an array.
# Adding 002/seg/71.png into an array.
# Adding 002/seg/72.png into an array.
# Adding 002/seg/73.png into an array.
# Adding 002/seg/74.png into an array.
# Adding 002/seg/75.png into an array.
# Adding 002/seg/76.png into an array.
# Adding 002/seg/77.png into an array.
# Adding 002/seg/78.png into an array.
# Adding 002/seg/79.png into an array.
# Adding 002/seg/8.png into an array.
# Adding 002/seg/80.png into an array.
# Adding 002/seg/81.png into an array.
# Adding 002/seg/82.png into an array.
# Adding 002/seg/83.png into an array.
# Adding 002/seg/84.png into an array.
# Adding 002/seg/85.png into an array.
# Adding 002/seg/86.png into an array.
# Adding 002/seg/87.png into an array.
# Adding 002/seg/88.png into an array.
# Adding 002/seg/89.png into an array.
# Adding 002/seg/9.png into an array.
# Adding 002/seg/90.png into an array.
# Adding 002/seg/91.png into an array.
# Adding 002/seg/92.png into an array.
# Adding 002/seg/93.png into an array.
# Adding 002/seg/94.png into an array.
# Adding 002/seg/95.png into an array.
# Adding 002/seg/96.png into an array.
# Adding 002/seg/97.png into an array.
# Adding 002/seg/98.png into an array.
# Adding 002/seg/99.png into an array.
# Adding 002/t1/0.png into an array.
# Adding 002/t1/1.png into an array.
# Adding 002/t1/10.png into an array.
# Adding 002/t1/100.png into an array.
# Adding 002/t1/101.png into an array.
# Adding 002/t1/102.png into an array.
# Adding 002/t1/103.png into an array.
# Adding 002/t1/104.png into an array.
# Adding 002/t1/105.png into an array.
# Adding 002/t1/106.png into an array.
# Adding 002/t1/107.png into an array.
# Adding 002/t1/108.png into an array.
# Adding 002/t1/109.png into an array.
# Adding 002/t1/11.png into an array.
# Adding 002/t1/110.png into an array.
# Adding 002/t1/111.png into an array.
# Adding 002/t1/112.png into an array.
# Adding 002/t1/113.png into an array.
# Adding 002/t1/114.png into an array.
# Adding 002/t1/115.png into an array.
# Adding 002/t1/116.png into an array.
# Adding 002/t1/117.png into an array.
# Adding 002/t1/118.png into an array.
# Adding 002/t1/119.png into an array.
# Adding 002/t1/12.png into an array.
# Adding 002/t1/120.png into an array.
# Adding 002/t1/121.png into an array.
# Adding 002/t1/122.png into an array.
# Adding 002/t1/123.png into an array.
# Adding 002/t1/124.png into an array.
# Adding 002/t1/125.png into an array.
# Adding 002/t1/126.png into an array.
# Adding 002/t1/127.png into an array.
# Adding 002/t1/128.png into an array.
# Adding 002/t1/129.png into an array.
# Adding 002/t1/13.png into an array.
# Adding 002/t1/130.png into an array.
# Adding 002/t1/131.png into an array.
# Adding 002/t1/132.png into an array.
# Adding 002/t1/133.png into an array.
# Adding 002/t1/134.png into an array.
# Adding 002/t1/135.png into an array.
# Adding 002/t1/136.png into an array.
# Adding 002/t1/137.png into an array.
# Adding 002/t1/138.png into an array.
# Adding 002/t1/139.png into an array.
# Adding 002/t1/14.png into an array.
# Adding 002/t1/140.png into an array.
# Adding 002/t1/141.png into an array.
# Adding 002/t1/142.png into an array.
# Adding 002/t1/143.png into an array.
# Adding 002/t1/144.png into an array.
# Adding 002/t1/145.png into an array.
# Adding 002/t1/146.png into an array.
# Adding 002/t1/147.png into an array.
# Adding 002/t1/148.png into an array.
# Adding 002/t1/149.png into an array.
# Adding 002/t1/15.png into an array.
# Adding 002/t1/150.png into an array.
# Adding 002/t1/151.png into an array.
# Adding 002/t1/152.png into an array.
# Adding 002/t1/153.png into an array.
# Adding 002/t1/154.png into an array.
# Adding 002/t1/16.png into an array.
# Adding 002/t1/17.png into an array.
# Adding 002/t1/18.png into an array.
# Adding 002/t1/19.png into an array.
# Adding 002/t1/2.png into an array.
# Adding 002/t1/20.png into an array.
# Adding 002/t1/21.png into an array.
# Adding 002/t1/22.png into an array.
# Adding 002/t1/23.png into an array.
# Adding 002/t1/24.png into an array.
# Adding 002/t1/25.png into an array.
# Adding 002/t1/26.png into an array.
# Adding 002/t1/27.png into an array.
# Adding 002/t1/28.png into an array.
# Adding 002/t1/29.png into an array.
# Adding 002/t1/3.png into an array.
# Adding 002/t1/30.png into an array.
# Adding 002/t1/31.png into an array.
# Adding 002/t1/32.png into an array.
# Adding 002/t1/33.png into an array.
# Adding 002/t1/34.png into an array.
# Adding 002/t1/35.png into an array.
# Adding 002/t1/36.png into an array.
# Adding 002/t1/37.png into an array.
# Adding 002/t1/38.png into an array.
# Adding 002/t1/39.png into an array.
# Adding 002/t1/4.png into an array.
# Adding 002/t1/40.png into an array.
# Adding 002/t1/41.png into an array.
# Adding 002/t1/42.png into an array.
# Adding 002/t1/43.png into an array.
# Adding 002/t1/44.png into an array.
# Adding 002/t1/45.png into an array.
# Adding 002/t1/46.png into an array.
# Adding 002/t1/47.png into an array.
# Adding 002/t1/48.png into an array.
# Adding 002/t1/49.png into an array.
# Adding 002/t1/5.png into an array.
# Adding 002/t1/50.png into an array.
# Adding 002/t1/51.png into an array.
# Adding 002/t1/52.png into an array.
# Adding 002/t1/53.png into an array.
# Adding 002/t1/54.png into an array.
# Adding 002/t1/55.png into an array.
# Adding 002/t1/56.png into an array.
# Adding 002/t1/57.png into an array.
# Adding 002/t1/58.png into an array.
# Adding 002/t1/59.png into an array.
# Adding 002/t1/6.png into an array.
# Adding 002/t1/60.png into an array.
# Adding 002/t1/61.png into an array.
# Adding 002/t1/62.png into an array.
# Adding 002/t1/63.png into an array.
# Adding 002/t1/64.png into an array.
# Adding 002/t1/65.png into an array.
# Adding 002/t1/66.png into an array.
# Adding 002/t1/67.png into an array.
# Adding 002/t1/68.png into an array.
# Adding 002/t1/69.png into an array.
# Adding 002/t1/7.png into an array.
# Adding 002/t1/70.png into an array.
# Adding 002/t1/71.png into an array.
# Adding 002/t1/72.png into an array.
# Adding 002/t1/73.png into an array.
# Adding 002/t1/74.png into an array.
# Adding 002/t1/75.png into an array.
# Adding 002/t1/76.png into an array.
# Adding 002/t1/77.png into an array.
# Adding 002/t1/78.png into an array.
# Adding 002/t1/79.png into an array.
# Adding 002/t1/8.png into an array.
# Adding 002/t1/80.png into an array.
# Adding 002/t1/81.png into an array.
# Adding 002/t1/82.png into an array.
# Adding 002/t1/83.png into an array.
# Adding 002/t1/84.png into an array.
# Adding 002/t1/85.png into an array.
# Adding 002/t1/86.png into an array.
# Adding 002/t1/87.png into an array.
# Adding 002/t1/88.png into an array.
# Adding 002/t1/89.png into an array.
# Adding 002/t1/9.png into an array.
# Adding 002/t1/90.png into an array.
# Adding 002/t1/91.png into an array.
# Adding 002/t1/92.png into an array.
# Adding 002/t1/93.png into an array.
# Adding 002/t1/94.png into an array.
# Adding 002/t1/95.png into an array.
# Adding 002/t1/96.png into an array.
# Adding 002/t1/97.png into an array.
# Adding 002/t1/98.png into an array.
# Adding 002/t1/99.png into an array.
# Adding 002/t1ce/0.png into an array.
# Adding 002/t1ce/1.png into an array.
# Adding 002/t1ce/10.png into an array.
# Adding 002/t1ce/100.png into an array.
# Adding 002/t1ce/101.png into an array.
# Adding 002/t1ce/102.png into an array.
# Adding 002/t1ce/103.png into an array.
# Adding 002/t1ce/104.png into an array.
# Adding 002/t1ce/105.png into an array.
# Adding 002/t1ce/106.png into an array.
# Adding 002/t1ce/107.png into an array.
# Adding 002/t1ce/108.png into an array.
# Adding 002/t1ce/109.png into an array.
# Adding 002/t1ce/11.png into an array.
# Adding 002/t1ce/110.png into an array.
# Adding 002/t1ce/111.png into an array.
# Adding 002/t1ce/112.png into an array.
# Adding 002/t1ce/113.png into an array.
# Adding 002/t1ce/114.png into an array.
# Adding 002/t1ce/115.png into an array.
# Adding 002/t1ce/116.png into an array.
# Adding 002/t1ce/117.png into an array.
# Adding 002/t1ce/118.png into an array.
# Adding 002/t1ce/119.png into an array.
# Adding 002/t1ce/12.png into an array.
# Adding 002/t1ce/120.png into an array.
# Adding 002/t1ce/121.png into an array.
# Adding 002/t1ce/122.png into an array.
# Adding 002/t1ce/123.png into an array.
# Adding 002/t1ce/124.png into an array.
# Adding 002/t1ce/125.png into an array.
# Adding 002/t1ce/126.png into an array.
# Adding 002/t1ce/127.png into an array.
# Adding 002/t1ce/128.png into an array.
# Adding 002/t1ce/129.png into an array.
# Adding 002/t1ce/13.png into an array.
# Adding 002/t1ce/130.png into an array.
# Adding 002/t1ce/131.png into an array.
# Adding 002/t1ce/132.png into an array.
# Adding 002/t1ce/133.png into an array.
# Adding 002/t1ce/134.png into an array.
# Adding 002/t1ce/135.png into an array.
# Adding 002/t1ce/136.png into an array.
# Adding 002/t1ce/137.png into an array.
# Adding 002/t1ce/138.png into an array.
# Adding 002/t1ce/139.png into an array.
# Adding 002/t1ce/14.png into an array.
# Adding 002/t1ce/140.png into an array.
# Adding 002/t1ce/141.png into an array.
# Adding 002/t1ce/142.png into an array.
# Adding 002/t1ce/143.png into an array.
# Adding 002/t1ce/144.png into an array.
# Adding 002/t1ce/145.png into an array.
# Adding 002/t1ce/146.png into an array.
# Adding 002/t1ce/147.png into an array.
# Adding 002/t1ce/148.png into an array.
# Adding 002/t1ce/149.png into an array.
# Adding 002/t1ce/15.png into an array.
# Adding 002/t1ce/150.png into an array.
# Adding 002/t1ce/151.png into an array.
# Adding 002/t1ce/152.png into an array.
# Adding 002/t1ce/153.png into an array.
# Adding 002/t1ce/154.png into an array.
# Adding 002/t1ce/16.png into an array.
# Adding 002/t1ce/17.png into an array.
# Adding 002/t1ce/18.png into an array.
# Adding 002/t1ce/19.png into an array.
# Adding 002/t1ce/2.png into an array.
# Adding 002/t1ce/20.png into an array.
# Adding 002/t1ce/21.png into an array.
# Adding 002/t1ce/22.png into an array.
# Adding 002/t1ce/23.png into an array.
# Adding 002/t1ce/24.png into an array.
# Adding 002/t1ce/25.png into an array.
# Adding 002/t1ce/26.png into an array.
# Adding 002/t1ce/27.png into an array.
# Adding 002/t1ce/28.png into an array.
# Adding 002/t1ce/29.png into an array.
# Adding 002/t1ce/3.png into an array.
# Adding 002/t1ce/30.png into an array.
# Adding 002/t1ce/31.png into an array.
# Adding 002/t1ce/32.png into an array.
# Adding 002/t1ce/33.png into an array.
# Adding 002/t1ce/34.png into an array.
# Adding 002/t1ce/35.png into an array.
# Adding 002/t1ce/36.png into an array.
# Adding 002/t1ce/37.png into an array.
# Adding 002/t1ce/38.png into an array.
# Adding 002/t1ce/39.png into an array.
# Adding 002/t1ce/4.png into an array.
# Adding 002/t1ce/40.png into an array.
# Adding 002/t1ce/41.png into an array.
# Adding 002/t1ce/42.png into an array.
# Adding 002/t1ce/43.png into an array.
# Adding 002/t1ce/44.png into an array.
# Adding 002/t1ce/45.png into an array.
# Adding 002/t1ce/46.png into an array.
# Adding 002/t1ce/47.png into an array.
# Adding 002/t1ce/48.png into an array.
# Adding 002/t1ce/49.png into an array.
# Adding 002/t1ce/5.png into an array.
# Adding 002/t1ce/50.png into an array.
# Adding 002/t1ce/51.png into an array.
# Adding 002/t1ce/52.png into an array.
# Adding 002/t1ce/53.png into an array.
# Adding 002/t1ce/54.png into an array.
# Adding 002/t1ce/55.png into an array.
# Adding 002/t1ce/56.png into an array.
# Adding 002/t1ce/57.png into an array.
# Adding 002/t1ce/58.png into an array.
# Adding 002/t1ce/59.png into an array.
# Adding 002/t1ce/6.png into an array.
# Adding 002/t1ce/60.png into an array.
# Adding 002/t1ce/61.png into an array.
# Adding 002/t1ce/62.png into an array.
# Adding 002/t1ce/63.png into an array.
# Adding 002/t1ce/64.png into an array.
# Adding 002/t1ce/65.png into an array.
# Adding 002/t1ce/66.png into an array.
# Adding 002/t1ce/67.png into an array.
# Adding 002/t1ce/68.png into an array.
# Adding 002/t1ce/69.png into an array.
# Adding 002/t1ce/7.png into an array.
# Adding 002/t1ce/70.png into an array.
# Adding 002/t1ce/71.png into an array.
# Adding 002/t1ce/72.png into an array.
# Adding 002/t1ce/73.png into an array.
# Adding 002/t1ce/74.png into an array.
# Adding 002/t1ce/75.png into an array.
# Adding 002/t1ce/76.png into an array.
# Adding 002/t1ce/77.png into an array.
# Adding 002/t1ce/78.png into an array.
# Adding 002/t1ce/79.png into an array.
# Adding 002/t1ce/8.png into an array.
# Adding 002/t1ce/80.png into an array.
# Adding 002/t1ce/81.png into an array.
# Adding 002/t1ce/82.png into an array.
# Adding 002/t1ce/83.png into an array.
# Adding 002/t1ce/84.png into an array.
# Adding 002/t1ce/85.png into an array.
# Adding 002/t1ce/86.png into an array.
# Adding 002/t1ce/87.png into an array.
# Adding 002/t1ce/88.png into an array.
# Adding 002/t1ce/89.png into an array.
# Adding 002/t1ce/9.png into an array.
# Adding 002/t1ce/90.png into an array.
# Adding 002/t1ce/91.png into an array.
# Adding 002/t1ce/92.png into an array.
# Adding 002/t1ce/93.png into an array.
# Adding 002/t1ce/94.png into an array.
# Adding 002/t1ce/95.png into an array.
# Adding 002/t1ce/96.png into an array.
# Adding 002/t1ce/97.png into an array.
# Adding 002/t1ce/98.png into an array.
# Adding 002/t1ce/99.png into an array.
# Adding 002/t2/0.png into an array.
# Adding 002/t2/1.png into an array.
# Adding 002/t2/10.png into an array.
# Adding 002/t2/100.png into an array.
# Adding 002/t2/101.png into an array.
# Adding 002/t2/102.png into an array.
# Adding 002/t2/103.png into an array.
# Adding 002/t2/104.png into an array.
# Adding 002/t2/105.png into an array.
# Adding 002/t2/106.png into an array.
# Adding 002/t2/107.png into an array.
# Adding 002/t2/108.png into an array.
# Adding 002/t2/109.png into an array.
# Adding 002/t2/11.png into an array.
# Adding 002/t2/110.png into an array.
# Adding 002/t2/111.png into an array.
# Adding 002/t2/112.png into an array.
# Adding 002/t2/113.png into an array.
# Adding 002/t2/114.png into an array.
# Adding 002/t2/115.png into an array.
# Adding 002/t2/116.png into an array.
# Adding 002/t2/117.png into an array.
# Adding 002/t2/118.png into an array.
# Adding 002/t2/119.png into an array.
# Adding 002/t2/12.png into an array.
# Adding 002/t2/120.png into an array.
# Adding 002/t2/121.png into an array.
# Adding 002/t2/122.png into an array.
# Adding 002/t2/123.png into an array.
# Adding 002/t2/124.png into an array.
# Adding 002/t2/125.png into an array.
# Adding 002/t2/126.png into an array.
# Adding 002/t2/127.png into an array.
# Adding 002/t2/128.png into an array.
# Adding 002/t2/129.png into an array.
# Adding 002/t2/13.png into an array.
# Adding 002/t2/130.png into an array.
# Adding 002/t2/131.png into an array.
# Adding 002/t2/132.png into an array.
# Adding 002/t2/133.png into an array.
# Adding 002/t2/134.png into an array.
# Adding 002/t2/135.png into an array.
# Adding 002/t2/136.png into an array.
# Adding 002/t2/137.png into an array.
# Adding 002/t2/138.png into an array.
# Adding 002/t2/139.png into an array.
# Adding 002/t2/14.png into an array.
# Adding 002/t2/140.png into an array.
# Adding 002/t2/141.png into an array.
# Adding 002/t2/142.png into an array.
# Adding 002/t2/143.png into an array.
# Adding 002/t2/144.png into an array.
# Adding 002/t2/145.png into an array.
# Adding 002/t2/146.png into an array.
# Adding 002/t2/147.png into an array.
# Adding 002/t2/148.png into an array.
# Adding 002/t2/149.png into an array.
# Adding 002/t2/15.png into an array.
# Adding 002/t2/150.png into an array.
# Adding 002/t2/151.png into an array.
# Adding 002/t2/152.png into an array.
# Adding 002/t2/153.png into an array.
# Adding 002/t2/154.png into an array.
# Adding 002/t2/16.png into an array.
# Adding 002/t2/17.png into an array.
# Adding 002/t2/18.png into an array.
# Adding 002/t2/19.png into an array.
# Adding 002/t2/2.png into an array.
# Adding 002/t2/20.png into an array.
# Adding 002/t2/21.png into an array.
# Adding 002/t2/22.png into an array.
# Adding 002/t2/23.png into an array.
# Adding 002/t2/24.png into an array.
# Adding 002/t2/25.png into an array.
# Adding 002/t2/26.png into an array.
# Adding 002/t2/27.png into an array.
# Adding 002/t2/28.png into an array.
# Adding 002/t2/29.png into an array.
# Adding 002/t2/3.png into an array.
# Adding 002/t2/30.png into an array.
# Adding 002/t2/31.png into an array.
# Adding 002/t2/32.png into an array.
# Adding 002/t2/33.png into an array.
# Adding 002/t2/34.png into an array.
# Adding 002/t2/35.png into an array.
# Adding 002/t2/36.png into an array.
# Adding 002/t2/37.png into an array.
# Adding 002/t2/38.png into an array.
# Adding 002/t2/39.png into an array.
# Adding 002/t2/4.png into an array.
# Adding 002/t2/40.png into an array.
# Adding 002/t2/41.png into an array.
# Adding 002/t2/42.png into an array.
# Adding 002/t2/43.png into an array.
# Adding 002/t2/44.png into an array.
# Adding 002/t2/45.png into an array.
# Adding 002/t2/46.png into an array.
# Adding 002/t2/47.png into an array.
# Adding 002/t2/48.png into an array.
# Adding 002/t2/49.png into an array.
# Adding 002/t2/5.png into an array.
# Adding 002/t2/50.png into an array.
# Adding 002/t2/51.png into an array.
# Adding 002/t2/52.png into an array.
# Adding 002/t2/53.png into an array.
# Adding 002/t2/54.png into an array.
# Adding 002/t2/55.png into an array.
# Adding 002/t2/56.png into an array.
# Adding 002/t2/57.png into an array.
# Adding 002/t2/58.png into an array.
# Adding 002/t2/59.png into an array.
# Adding 002/t2/6.png into an array.
# Adding 002/t2/60.png into an array.
# Adding 002/t2/61.png into an array.
# Adding 002/t2/62.png into an array.
# Adding 002/t2/63.png into an array.
# Adding 002/t2/64.png into an array.
# Adding 002/t2/65.png into an array.
# Adding 002/t2/66.png into an array.
# Adding 002/t2/67.png into an array.
# Adding 002/t2/68.png into an array.
# Adding 002/t2/69.png into an array.
# Adding 002/t2/7.png into an array.
# Adding 002/t2/70.png into an array.
# Adding 002/t2/71.png into an array.
# Adding 002/t2/72.png into an array.
# Adding 002/t2/73.png into an array.
# Adding 002/t2/74.png into an array.
# Adding 002/t2/75.png into an array.
# Adding 002/t2/76.png into an array.
# Adding 002/t2/77.png into an array.
# Adding 002/t2/78.png into an array.
# Adding 002/t2/79.png into an array.
# Adding 002/t2/8.png into an array.
# Adding 002/t2/80.png into an array.
# Adding 002/t2/81.png into an array.
# Adding 002/t2/82.png into an array.
# Adding 002/t2/83.png into an array.
# Adding 002/t2/84.png into an array.
# Adding 002/t2/85.png into an array.
# Adding 002/t2/86.png into an array.
# Adding 002/t2/87.png into an array.
# Adding 002/t2/88.png into an array.
# Adding 002/t2/89.png into an array.
# Adding 002/t2/9.png into an array.
# Adding 002/t2/90.png into an array.
# Adding 002/t2/91.png into an array.
# Adding 002/t2/92.png into an array.
# Adding 002/t2/93.png into an array.
# Adding 002/t2/94.png into an array.
# Adding 002/t2/95.png into an array.
# Adding 002/t2/96.png into an array.
# Adding 002/t2/97.png into an array.
# Adding 002/t2/98.png into an array.
# Adding 002/t2/99.png into an array.
# Training Gan now:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 9
#       7 brain_array = load_images(bucket_name=bucket, folder_path=folder_path, folder_suffix=key)
#       8 print("Training Gan now:")
# ----> 9 train_gan(generator=chemocraft_generator, latent_dim=dim, discriminator=chemocraft_discriminator, gan=chemocraft_gan, training_array=brain_array, batch_size=5)
#      10 print(f"Epoch {epoch + 1}/{epochs}")
#
# Cell In[9], line 14, in train_gan(generator, latent_dim, discriminator, gan, training_array, batch_size)
#      11 fake_slices = generator.predict(noise)
#      13 # Train the discriminator
# ---> 14 d_loss_real = discriminator.train_on_batch(real_slices, np.ones((batch_size, 1)))
#      15 d_loss_fake = discriminator.train_on_batch(fake_slices, np.zeros((batch_size, 1)))
#      16 d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
#
# File c:\Users\User\anaconda3\envs\myenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:549, in TensorFlowTrainer.train_on_batch(self, x, y, sample_weight, class_weight, return_dict)
#     546 def data():
#     547     yield (x, y, sample_weight)
# --> 549 logs = self.train_function(data())
#     550 logs = tree.map_structure(lambda x: np.array(x), logs)
#     551 if return_dict:
#
# File c:\Users\User\anaconda3\envs\myenv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\User\anaconda3\envs\myenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:121, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator(iterator)
#     119 """Runs a single training step given a Dataset iterator."""
#     120 data = next(iterator)
# --> 121 outputs = self.distribute_strategy.run(
#     122     one_step_on_data, args=(data,)
#     123 )
#     124 outputs = reduce_per_replica(
#     125     outputs,
#     126     self.distribute_strategy,
#     127     reduction="auto",
#     128 )
#     129 return outputs
#
# File c:\Users\User\anaconda3\envs\myenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:108, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_data(data)
#     105 @tf.autograph.experimental.do_not_convert
#     106 def one_step_on_data(data):
#     107     """Runs a single training step on a batch of data."""
# --> 108     return self.train_step(data)
#
# File c:\Users\User\anaconda3\envs\myenv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:61, in TensorFlowTrainer.train_step(self, data)
#      53     y_pred = self(x)
#      54 loss = self._compute_loss(
#      55     x=x,
#      56     y=y,
#    (...)
#      59     training=True,
#      60 )
# ---> 61 self._loss_tracker.update_state(
#      62     loss, sample_weight=tf.shape(tree.flatten(x)[0])[0]
#      63 )
#      64 if self.optimizer is not None:
#      65     loss = self.optimizer.scale_loss(loss)
#
# AttributeError: 'NoneType' object has no attribute 'update_state'
